# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("final_performance_v4.csv", parse_dates=['방송일시','date', 'real_date'])
data
# Out:
#        Unnamed: 0                방송일시  노출(분)  마더코드  상품코드             상품명  상품군  \
# 0               0 2019-01-01 06:00:00   20.0   296   891   테이트 남성 셀린니트3종    6
# 1               1 2019-01-01 06:00:00   20.0   296   898   테이트 여성 셀린니트3종    6
# 2               2 2019-01-01 06:20:00   20.0   296   891   테이트 남성 셀린니트3종    6
# 3               3 2019-01-01 06:20:00   20.0   296   898   테이트 여성 셀린니트3종    6
# 4               4 2019-01-01 06:40:00   20.0   296   891   테이트 남성 셀린니트3종    6
# ...           ...                 ...    ...   ...   ...             ...  ...
# 35374       35374 2019-12-31 23:40:00   20.0   374  1130   일시불쿠첸압력밥솥 6인용    9
# 35375       35375 2020-01-01 00:00:00   20.0   374  1124  무이자쿠첸압력밥솥 10인용    9
# 35376       35376 2020-01-01 00:00:00   20.0   374  1129  일시불쿠첸압력밥솥 10인용    9
# 35377       35377 2020-01-01 00:00:00   20.0   374  1125   무이자쿠첸압력밥솥 6인용    9
# 35378       35378 2020-01-01 00:00:00   20.0   374  1130   일시불쿠첸압력밥솥 6인용    9
#
#          판매단가          취급액       date  ...  g_3 s_0  s_1  w_0 w_1  w_2  w_3  \
# 0       39900    2099000.0 2019-01-01  ...    0   0    0    0   0    0    0
# 1       39900    4371000.0 2019-01-01  ...    0   0    0    0   0    0    0
# 2       39900    3262000.0 2019-01-01  ...    0   1    0    0   0    0    0
# 3       39900    6955000.0 2019-01-01  ...    0   1    0    0   0    0    0
# 4       39900    6672000.0 2019-01-01  ...    0   0    1    0   0    0    0
# ...       ...          ...        ...  ...  ...  ..  ...  ...  ..  ...  ...
# 35374  148000   10157000.0 2019-12-31  ...    1   1    0    0   0    0    0
# 35375  178000   50929000.0 2019-12-31  ...    1   0    1    0   0    0    0
# 35376  168000  104392000.0 2019-12-31  ...    1   0    1    0   0    0    0
# 35377  158000   13765000.0 2019-12-31  ...    1   0    1    0   0    0    0
# 35378  148000   46608000.0 2019-12-31  ...    1   0    1    0   0    0    0
#
#        w_4  w_5     cpi
# 0        0    0  104.03
# 1        0    0  104.03
# 2        0    0  104.03
# 3        0    0  104.03
# 4        0    0  104.03
# ...    ...  ...     ...
# 35374    0    0  105.51
# 35375    0    0  106.26
# 35376    0    0  106.26
# 35377    0    0  106.26
# 35378    0    0  106.26
#
# [35379 rows x 55 columns]

# %%
import sklearn
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import gc

# %%
use_var = ['마더코드', '상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage', 'prime', 'IsHoliday', '노출(분)', '판매단가', '취급액', '지속휴일수', 'TEMP', 'HUM', 'cpi']
Data = data[use_var]

# %%
X = Data.drop(['취급액'], axis = 1)
Y = Data[['취급액']]
print("data shape : ", X.shape)
print("label shape : " , Y.shape)
# Out:
# data shape :  (35379, 15)
# label shape :  (35379, 1)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size = 0.1, random_state = 123457)
print("x_train shape : ", x_train.shape)
print("y_train shape : ", y_train.shape)
print("x_valid shape : ", x_valid.shape)
print("y_valid shape : ", y_valid.shape)
# Out:
# x_train shape :  (31841, 15)
# y_train shape :  (31841, 1)
# x_valid shape :  (3538, 15)
# y_valid shape :  (3538, 1)

# %% [markdown]
# ## Make valid data

# %%
pd.set_option('mode.chained_assignment',  None)
def goods_code_encoding(value,code_set, price, mother, cat):
    if value in code_set:
        return value
    else:
        if mother in x_train['마더코드']:
            frame = x_train[x_train['마더코드']==mother]
            frame['diff'] =  abs(frame['판매단가'] - price)
            goods_code = frame[frame['diff']==min(frame['diff'])].iloc[0,1]
            return goods_code
        else:
            frame = x_train[x_train['상품군']==cat]
            frame['diff'] =  abs(frame['판매단가'] - price)
            goods_code = frame[frame['diff']==min(frame['diff'])].iloc[0,1]
            return goods_code

# %%
make_valid_cols = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage', 'IsHoliday', '노출(분)', '판매단가', '지속휴일수', 'TEMP', 'HUM', 'cpi']
to_cat = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage']
train_goods_set = set(x_train['상품코드'])
row = x_valid.iloc[0]
x_valid.iloc[0] = goods_code_encoding(row['상품코드'],train_goods_set, row['판매단가'], row['마더코드'], row['상품군'])
for i in range(1, len(x_valid)):
    row = x_valid.iloc[i]
    x_valid.iloc[i] = goods_code_encoding(row['상품코드'], train_goods_set, row['판매단가'], row['마더코드'], row['상품군'])

for col in to_cat:
    x_valid[col] = x_valid[col].astype('category') 
    
print("x_valid shape : ", x_valid.shape)
# Out:
# x_valid shape :  (3538, 15)

# %% [markdown]
# ## Make train data

# %%
make_train_cols = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage', 'IsHoliday', '노출(분)', '판매단가', '지속휴일수', 'TEMP', 'HUM', 'cpi']
to_cat = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage']
train_goods_set = set(x_train['상품코드'])
for col in to_cat:
    x_train[col] = x_train[col].astype('category') 
    
print("x_train shape : ", x_train.shape)
# Out:
# x_train shape :  (31841, 15)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31841 entries, 15609 to 29649
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   마더코드        31841 non-null  int64
#  1   상품코드        31841 non-null  category
#  2   상품군         31841 non-null  category
#  3   week        31841 non-null  category
#  4   hour        31841 non-null  category
#  5   weekofyear  31841 non-null  category
#  6   stage       31841 non-null  category
#  7   prime       31841 non-null  int64
#  8   IsHoliday   31841 non-null  float64
#  9   노출(분)       31841 non-null  float64
#  10  판매단가        31841 non-null  int64
#  11  지속휴일수       31841 non-null  float64
#  12  TEMP        31841 non-null  float64
#  13  HUM         31841 non-null  float64
#  14  cpi         31841 non-null  float64
# dtypes: category(6), float64(6), int64(3)
# memory usage: 4.0 MB

# %%
x_valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3538 entries, 3611 to 24239
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   마더코드        3538 non-null   float64
#  1   상품코드        3538 non-null   category
#  2   상품군         3538 non-null   category
#  3   week        3538 non-null   category
#  4   hour        3538 non-null   category
#  5   weekofyear  3538 non-null   category
#  6   stage       3538 non-null   category
#  7   prime       3538 non-null   float64
#  8   IsHoliday   3538 non-null   float64
#  9   노출(분)       3538 non-null   float64
#  10  판매단가        3538 non-null   float64
#  11  지속휴일수       3538 non-null   float64
#  12  TEMP        3538 non-null   float64
#  13  HUM         3538 non-null   float64
#  14  cpi         3538 non-null   float64
# dtypes: category(6), float64(9)
# memory usage: 613.6 KB

# %% [markdown]
# ## lightgbm 데이터셋으로 변환

# %%
import lightgbm as lgb

train_ds = lgb.Dataset(x_train, label = y_train) 
valid_ds = lgb.Dataset(x_valid, label = y_valid)

# %% [markdown]
# ## 파라미터 세팅

# %%
params = {'learning_rate': 0.05, 
          'max_depth': -1, 
          'boosting': 'dart', 
          'objective': 'regression', 
          'metric': 'mape', 
          'is_training_metric': True, 
          'num_leaves': 144, 
          'feature_fraction': 0.9, 
          'bagging_fraction': 0.7, 
          'bagging_freq': 5, 
          'seed':123457}

# %% [markdown]
# ## 모델 훈련

# %%
model = lgb.train(params, train_ds, 100000, valid_ds, verbose_eval=100, early_stopping_rounds=100)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2897
# [LightGBM] [Info] Number of data points in the train set: 31841, number of used features: 15
# [LightGBM] [Info] Start training from score 23136023.429917
# [100]	valid_0's mape: 1.02126
# [200]	valid_0's mape: 1.02051
# [300]	valid_0's mape: 1.02488
# [400]	valid_0's mape: 1.0739
# [500]	valid_0's mape: 1.08765
# [600]	valid_0's mape: 1.12808
# [700]	valid_0's mape: 1.05004
# [800]	valid_0's mape: 1.02926
# [900]	valid_0's mape: 0.888826
# [1000]	valid_0's mape: 0.831656
# [1100]	valid_0's mape: 0.849152
# [1200]	valid_0's mape: 0.868018
# [1300]	valid_0's mape: 0.897627
# [1400]	valid_0's mape: 0.889491
# [1500]	valid_0's mape: 0.925
# [1600]	valid_0's mape: 0.898467
# [1700]	valid_0's mape: 0.896961
# [1800]	valid_0's mape: 0.865071
# [1900]	valid_0's mape: 0.842949
# [2000]	valid_0's mape: 0.804917
# [2100]	valid_0's mape: 0.785076
# [2200]	valid_0's mape: 0.746747
# [2300]	valid_0's mape: 0.745274
# [2400]	valid_0's mape: 0.732117
# [2500]	valid_0's mape: 0.729068
# [2600]	valid_0's mape: 0.721732
# [2700]	valid_0's mape: 0.706634
# [2800]	valid_0's mape: 0.723207
# [2900]	valid_0's mape: 0.718022
# [3000]	valid_0's mape: 0.694467
# [3100]	valid_0's mape: 0.700204
# [3200]	valid_0's mape: 0.690034
# [3300]	valid_0's mape: 0.685711
# [3400]	valid_0's mape: 0.680455
# [3500]	valid_0's mape: 0.69009
# [3600]	valid_0's mape: 0.682868
# [3700]	valid_0's mape: 0.674409
# [3800]	valid_0's mape: 0.661599
# [3900]	valid_0's mape: 0.660208
# [4000]	valid_0's mape: 0.656664
# [4100]	valid_0's mape: 0.653335
# [4200]	valid_0's mape: 0.650994
# [4300]	valid_0's mape: 0.649377
# [4400]	valid_0's mape: 0.643587
# [4500]	valid_0's mape: 0.641644
# [4600]	valid_0's mape: 0.641297
# [4700]	valid_0's mape: 0.640632
# [4800]	valid_0's mape: 0.644604
# [4900]	valid_0's mape: 0.643482
# [5000]	valid_0's mape: 0.645719
# [5100]	valid_0's mape: 0.649377
# [5200]	valid_0's mape: 0.644757
# [5300]	valid_0's mape: 0.642867
# [5400]	valid_0's mape: 0.641308
# [5500]	valid_0's mape: 0.642416
# [5600]	valid_0's mape: 0.651299
# [5700]	valid_0's mape: 0.652887
# [5800]	valid_0's mape: 0.654095
# [5900]	valid_0's mape: 0.651252
# [6000]	valid_0's mape: 0.649312
# [6100]	valid_0's mape: 0.653685
# [6200]	valid_0's mape: 0.655882
# [6300]	valid_0's mape: 0.647964
# [6400]	valid_0's mape: 0.64544
# [6500]	valid_0's mape: 0.643599
# [6600]	valid_0's mape: 0.644011
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-97-bab23fe5324a> in <module>
# ----> 1 model = lgb.train(params, train_ds, 100000, valid_ds, verbose_eval=100, early_stopping_rounds=100)
#
# C:\ProgramData\Anaconda3\envs\tensor\lib\site-packages\lightgbm\engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     250                                     evaluation_result_list=None))
#     251
# --> 252         booster.update(fobj=fobj)
#     253
#     254         evaluation_result_list = []
#
# C:\ProgramData\Anaconda3\envs\tensor\lib\site-packages\lightgbm\basic.py in update(self, train_set, fobj)
#    2370             _safe_call(_LIB.LGBM_BoosterUpdateOneIter(
#    2371                 self.handle,
# -> 2372                 ctypes.byref(is_finished)))
#    2373             self.__is_predicted_cur_iter = [False for _ in range_(self.__num_dataset)]
#    2374             return is_finished.value == 1
#
# KeyboardInterrupt:

# %%
predict_train = model.predict(x_train).reshape(-1, 1)
predict_test = model.predict(x_valid).reshape(-1, 1)

# %%
import numpy as np

def MAPE(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
train_mape = MAPE(y_train, predict_train)
test_mape = MAPE(y_valid, predict_test)

print('train data MAPE: ', train_mape)
print('test data MAPE: ', test_mape)
# Out:
# train data MAPE:  81.69588757784115
# test data MAPE:  114.23964678929693
