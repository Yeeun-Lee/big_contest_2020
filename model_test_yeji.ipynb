# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("encoded_data.csv", parse_dates=['방송일시','date', 'real_date'])

# %%
data.columns
# Out:
# Index(['방송일시', '노출(분)', '마더코드', '상품코드', '상품명', '상품군', '판매단가', '취급액', 'date',
#        'week', 'time', 'hour', 'prime', 'real_date', 'IsHoliday', '지속휴일수',
#        'TEMP', 'HUM', 'weekofyear', 'stage', 'm_0', 'm_1', 'm_2', 'm_3', 'm_4',
#        'm_5', 'm_6', 'm_7', 'm_8', 'm_9', 'p_0', 'p_1', 'p_2', 'p_3', 'p_4',
#        'p_5', 'p_6', 'p_7', 'p_8', 'p_9', 'p_10', 'g_0', 'g_1', 'g_2', 'g_3',
#        's_0', 's_1', 'w_0', 'w_1', 'w_2', 'w_3', 'w_4', 'w_5'],
#       dtype='object')

# %% [markdown]
# ### 데이터 설명
# - m : 마더코드
# - p : 상품코드
# - g : 상품군
# - s : stage
# - w : weekofyear

# %%
data
# Out:
#                      방송일시  노출(분)  마더코드  상품코드             상품명  상품군    판매단가  \
# 0     2019-01-01 06:00:00   20.0   296   891   테이트 남성 셀린니트3종    6   39900
# 1     2019-01-01 06:00:00   20.0   296   898   테이트 여성 셀린니트3종    6   39900
# 2     2019-01-01 06:20:00   20.0   296   891   테이트 남성 셀린니트3종    6   39900
# 3     2019-01-01 06:20:00   20.0   296   898   테이트 여성 셀린니트3종    6   39900
# 4     2019-01-01 06:40:00   20.0   296   891   테이트 남성 셀린니트3종    6   39900
# ...                   ...    ...   ...   ...             ...  ...     ...
# 35374 2019-12-31 23:40:00   20.0   374  1130   일시불쿠첸압력밥솥 6인용    9  148000
# 35375 2020-01-01 00:00:00   20.0   374  1124  무이자쿠첸압력밥솥 10인용    9  178000
# 35376 2020-01-01 00:00:00   20.0   374  1129  일시불쿠첸압력밥솥 10인용    9  168000
# 35377 2020-01-01 00:00:00   20.0   374  1125   무이자쿠첸압력밥솥 6인용    9  158000
# 35378 2020-01-01 00:00:00   20.0   374  1130   일시불쿠첸압력밥솥 6인용    9  148000
#
#                취급액       date  week  ... g_2  g_3  s_0 s_1  w_0  w_1  w_2  \
# 0        2099000.0 2019-01-01     1  ...   1    0    0   0    0    0    0
# 1        4371000.0 2019-01-01     1  ...   1    0    0   0    0    0    0
# 2        3262000.0 2019-01-01     1  ...   1    0    1   0    0    0    0
# 3        6955000.0 2019-01-01     1  ...   1    0    1   0    0    0    0
# 4        6672000.0 2019-01-01     1  ...   1    0    0   1    0    0    0
# ...            ...        ...   ...  ...  ..  ...  ...  ..  ...  ...  ...
# 35374   10157000.0 2019-12-31     1  ...   0    1    1   0    0    0    0
# 35375   50929000.0 2019-12-31     1  ...   0    1    0   1    0    0    0
# 35376  104392000.0 2019-12-31     1  ...   0    1    0   1    0    0    0
# 35377   13765000.0 2019-12-31     1  ...   0    1    0   1    0    0    0
# 35378   46608000.0 2019-12-31     1  ...   0    1    0   1    0    0    0
#
#        w_3  w_4  w_5
# 0        0    0    0
# 1        0    0    0
# 2        0    0    0
# 3        0    0    0
# 4        0    0    0
# ...    ...  ...  ...
# 35374    0    0    0
# 35375    0    0    0
# 35376    0    0    0
# 35377    0    0    0
# 35378    0    0    0
#
# [35379 rows x 53 columns]

# %%
data2 = pd.read_csv("final_performance_v3.csv")
data2
# Out:
#        Unnamed: 0                 방송일시  노출(분)    마더코드    상품코드             상품명  \
# 0               0  2019-01-01 06:00:00   20.0  100346  201072   테이트 남성 셀린니트3종
# 1               1  2019-01-01 06:00:00   20.0  100346  201079   테이트 여성 셀린니트3종
# 2               2  2019-01-01 06:20:00   20.0  100346  201072   테이트 남성 셀린니트3종
# 3               3  2019-01-01 06:20:00   20.0  100346  201079   테이트 여성 셀린니트3종
# 4               4  2019-01-01 06:40:00   20.0  100346  201072   테이트 남성 셀린니트3종
# ...           ...                  ...    ...     ...     ...             ...
# 35374       35374  2019-12-31 23:40:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용
# 35375       35375  2020-01-01 00:00:00   20.0  100448  201383  무이자쿠첸압력밥솥 10인용
# 35376       35376  2020-01-01 00:00:00   20.0  100448  201390  일시불쿠첸압력밥솥 10인용
# 35377       35377  2020-01-01 00:00:00   20.0  100448  201384   무이자쿠첸압력밥솥 6인용
# 35378       35378  2020-01-01 00:00:00   20.0  100448  201391   일시불쿠첸압력밥솥 6인용
#
#       상품군    판매단가          취급액                 date  ...            real_date  \
# 0      의류   39900    2099000.0  2019-01-01 00:00:00  ...  2019-01-01 00:00:00
# 1      의류   39900    4371000.0  2019-01-01 00:00:00  ...  2019-01-01 00:00:00
# 2      의류   39900    3262000.0  2019-01-01 00:00:00  ...  2019-01-01 00:00:00
# 3      의류   39900    6955000.0  2019-01-01 00:00:00  ...  2019-01-01 00:00:00
# 4      의류   39900    6672000.0  2019-01-01 00:00:00  ...  2019-01-01 00:00:00
# ...    ..     ...          ...                  ...  ...                  ...
# 35374  주방  148000   10157000.0  2019-12-31 00:00:00  ...  2019-12-31 00:00:00
# 35375  주방  178000   50929000.0  2019-12-31 00:00:00  ...  2020-01-01 00:00:00
# 35376  주방  168000  104392000.0  2019-12-31 00:00:00  ...  2020-01-01 00:00:00
# 35377  주방  158000   13765000.0  2019-12-31 00:00:00  ...  2020-01-01 00:00:00
# 35378  주방  148000   46608000.0  2019-12-31 00:00:00  ...  2020-01-01 00:00:00
#
#         설명  IsHoliday  지속휴일수      TEMP        HUM  weekofyear  year  month  \
# 0       새해        1.0    1.0 -6.576974  63.524958           1  2019      1
# 1       새해        1.0    1.0 -6.576974  63.524958           1  2019      1
# 2       새해        1.0    1.0 -6.576974  63.524958           1  2019      1
# 3       새해        1.0    1.0 -6.576974  63.524958           1  2019      1
# 4       새해        1.0    1.0 -6.576974  63.524958           1  2019      1
# ...    ...        ...    ...       ...        ...         ...   ...    ...
# 35374  NaN        0.0    0.0 -6.021727  49.760460           1  2019     12
# 35375   새해        1.0    1.0 -5.782469  48.438717           1  2020      1
# 35376   새해        1.0    1.0 -5.782469  48.438717           1  2020      1
# 35377   새해        1.0    1.0 -5.782469  48.438717           1  2020      1
# 35378   새해        1.0    1.0 -5.782469  48.438717           1  2020      1
#
#           cpi
# 0      104.03
# 1      104.03
# 2      104.03
# 3      104.03
# 4      104.03
# ...       ...
# 35374  105.51
# 35375  106.26
# 35376  106.26
# 35377  106.26
# 35378  106.26
#
# [35379 rows x 24 columns]

# %%
data['cpi'] = data2['cpi']
data
# Out:
#                      방송일시  노출(분)  마더코드  상품코드             상품명  상품군    판매단가  \
# 0     2019-01-01 06:00:00   20.0   296   891   테이트 남성 셀린니트3종    6   39900
# 1     2019-01-01 06:00:00   20.0   296   898   테이트 여성 셀린니트3종    6   39900
# 2     2019-01-01 06:20:00   20.0   296   891   테이트 남성 셀린니트3종    6   39900
# 3     2019-01-01 06:20:00   20.0   296   898   테이트 여성 셀린니트3종    6   39900
# 4     2019-01-01 06:40:00   20.0   296   891   테이트 남성 셀린니트3종    6   39900
# ...                   ...    ...   ...   ...             ...  ...     ...
# 35374 2019-12-31 23:40:00   20.0   374  1130   일시불쿠첸압력밥솥 6인용    9  148000
# 35375 2020-01-01 00:00:00   20.0   374  1124  무이자쿠첸압력밥솥 10인용    9  178000
# 35376 2020-01-01 00:00:00   20.0   374  1129  일시불쿠첸압력밥솥 10인용    9  168000
# 35377 2020-01-01 00:00:00   20.0   374  1125   무이자쿠첸압력밥솥 6인용    9  158000
# 35378 2020-01-01 00:00:00   20.0   374  1130   일시불쿠첸압력밥솥 6인용    9  148000
#
#                취급액       date  week  ... g_3  s_0  s_1 w_0  w_1  w_2  w_3  \
# 0        2099000.0 2019-01-01     1  ...   0    0    0   0    0    0    0
# 1        4371000.0 2019-01-01     1  ...   0    0    0   0    0    0    0
# 2        3262000.0 2019-01-01     1  ...   0    1    0   0    0    0    0
# 3        6955000.0 2019-01-01     1  ...   0    1    0   0    0    0    0
# 4        6672000.0 2019-01-01     1  ...   0    0    1   0    0    0    0
# ...            ...        ...   ...  ...  ..  ...  ...  ..  ...  ...  ...
# 35374   10157000.0 2019-12-31     1  ...   1    1    0   0    0    0    0
# 35375   50929000.0 2019-12-31     1  ...   1    0    1   0    0    0    0
# 35376  104392000.0 2019-12-31     1  ...   1    0    1   0    0    0    0
# 35377   13765000.0 2019-12-31     1  ...   1    0    1   0    0    0    0
# 35378   46608000.0 2019-12-31     1  ...   1    0    1   0    0    0    0
#
#        w_4  w_5     cpi
# 0        0    0  104.03
# 1        0    0  104.03
# 2        0    0  104.03
# 3        0    0  104.03
# 4        0    0  104.03
# ...    ...  ...     ...
# 35374    0    0  105.51
# 35375    0    0  106.26
# 35376    0    0  106.26
# 35377    0    0  106.26
# 35378    0    0  106.26
#
# [35379 rows x 54 columns]

# %%
data.to_csv("final_performance_v4.csv", mode='w')

# %%
data = pd.read_csv("final_performance_v4.csv", parse_dates=['방송일시','date', 'real_date'])

# %%
import sklearn
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm
import gc

# %% [markdown]
# ## 사용 변수
# - **to_categorical** : 상품코드, 상품군, week, hour, weekofyear, stage
# - **dummy** : prime, IsHoliday,
# - **numeric** : 노출, 판매단가, 취급액, 지속휴일수, temp, hum, cpi

# %%
use_var = ['마더코드', '상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage', 'prime', 'IsHoliday', '노출(분)', '판매단가', '취급액', '지속휴일수', 'TEMP', 'HUM', 'cpi']
Data = data[use_var]

# %%
X = Data.drop(['취급액'], axis = 1)
Y = Data[['취급액']]
print("data shape : ", X.shape)
print("label shape : " , Y.shape)
# Out:
# data shape :  (35379, 15)
# label shape :  (35379, 1)

# %%
x_train, x_valid, y_train, y_valid = train_test_split(X, Y, test_size = 0.1, random_state = 123457)
print("x_train shape : ", x_train.shape)
print("y_train shape : ", y_train.shape)
print("x_valid shape : ", x_valid.shape)
print("y_valid shape : ", y_valid.shape)
# Out:
# x_train shape :  (31841, 15)
# y_train shape :  (31841, 1)
# x_valid shape :  (3538, 15)
# y_valid shape :  (3538, 1)

# %%
encoder = OneHotEncoder()
encoder.fit(np.array(x_train['상품코드']).reshape(-1,1))
onehot = encoder.transform(np.array(x_train['상품코드']).reshape(-1,1)).toarray()
print(onehot[0].shape)
# Out:
# (2024,)

# %%
np.array(x_train['prime']).reshape(-1,1)
# Out:
# array([[1],
#        [1],
#        [0],
#        ...,
#        [0],
#        [1],
#        [1]], dtype=int64)

# %% [markdown]
# ## make train data

# %%
make_train_cols = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage', 'IsHoliday', '노출(분)', '판매단가', '지속휴일수', 'TEMP', 'HUM', 'cpi']
to_cat = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage']
encoders = {}
X_train_input = np.array(x_train['prime']).reshape(-1,1)
for col in make_train_cols:
    if col in to_cat:
        encoder = OneHotEncoder()
        encoder.fit(np.array(x_train[col]).reshape(-1,1))
        encoders[col] = encoder
        onehot = encoder.transform(np.array(x_train[col]).reshape(-1,1)).toarray()
        X_train_input = np.concatenate((X_train_input,onehot), axis=1)
        print(col, onehot[0].shape, X_train_input[0].shape)
    else:
        inputs = np.array(x_train[col]).reshape(-1,1)
        X_train_input = np.concatenate((X_train_input,inputs), axis=1)
        print(col, onehot[0].shape, X_train_input[0].shape)
print("X_train_input shape : ", X_train_input.shape)
# Out:
# 상품코드 (2024,) (2025,)
# 상품군 (11,) (2036,)
# week (7,) (2043,)
# hour (21,) (2064,)
# weekofyear (52,) (2116,)
# stage (4,) (2120,)
# IsHoliday (4,) (2121,)
# 노출(분) (4,) (2122,)
# 판매단가 (4,) (2123,)
# 지속휴일수 (4,) (2124,)
# TEMP (4,) (2125,)
# HUM (4,) (2126,)
# cpi (4,) (2127,)
# X_train_input shape :  (31841, 2127)

# %% [markdown]
# ## make valid data

# %%
pd.set_option('mode.chained_assignment',  None)
def goods_code_encoding(value, encoder, price, mother, cat):
    if np.any(encoder.categories_[0] == value):
        return encoder.transform([[value]]).toarray()
    else:
        if mother in x_train['마더코드']:
            frame = x_train[x_train['마더코드']==mother]
            frame['diff'] =  abs(frame['판매단가'] - price)
            goods_code = frame[frame['diff']==min(frame['diff'])].iloc[0,1]
            return encoder.transform([[goods_code]]).toarray()
        else:
            frame = x_train[x_train['상품군']==cat]
            frame['diff'] =  abs(frame['판매단가'] - price)
            goods_code = frame[frame['diff']==min(frame['diff'])].iloc[0,1]
            return encoder.transform([[goods_code]]).toarray()

# %%
make_valid_cols = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage', 'IsHoliday', '노출(분)', '판매단가', '지속휴일수', 'TEMP', 'HUM', 'cpi']
to_cat = ['상품코드', '상품군', 'week', 'hour', 'weekofyear', 'stage']
X_valid_input = np.array(x_valid['prime']).reshape(-1,1)
for col in make_valid_cols:
    if col == '상품코드':
        row = x_valid.iloc[0]
        inputs = goods_code_encoding(row['상품코드'], encoders['상품코드'], row['판매단가'], row['마더코드'], row['상품군'])
        for i in range(1, len(x_valid)):
            row = x_valid.iloc[i]
            vector = goods_code_encoding(row['상품코드'], encoders['상품코드'], row['판매단가'], row['마더코드'], row['상품군'])
            inputs = np.append(inputs,vector, axis=0)
        X_valid_input = np.concatenate((X_valid_input,inputs), axis=1)
        print(col, inputs[0].shape, X_valid_input[0].shape)
    elif col in to_cat:
        onehot = encoders[col].transform(np.array(x_valid[col]).reshape(-1,1)).toarray()
        X_valid_input = np.concatenate((X_valid_input,onehot), axis=1)
        print(col, onehot[0].shape, X_valid_input[0].shape)
    else:
        inputs = np.array(x_valid[col]).reshape(-1,1)
        X_valid_input = np.concatenate((X_valid_input,inputs), axis=1)
        print(col, onehot[0].shape, X_valid_input[0].shape)
print("X_valid_input shape : ", X_valid_input.shape)
# Out:
# 상품코드 (2024,) (2025,)
# 상품군 (11,) (2036,)
# week (7,) (2043,)
# hour (21,) (2064,)
# weekofyear (52,) (2116,)
# stage (4,) (2120,)
# IsHoliday (4,) (2121,)
# 노출(분) (4,) (2122,)
# 판매단가 (4,) (2123,)
# 지속휴일수 (4,) (2124,)
# TEMP (4,) (2125,)
# HUM (4,) (2126,)
# cpi (4,) (2127,)
# X_valid_input shape :  (3538, 2127)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras import metrics
import tensorflow

# %%
model = Sequential()
model.add(Dense(512, input_dim=2127, activation='relu'))
model.add(Dense(128, activation='relu'))
#model.add(Dense(32, activation='relu'))
model.add(Dense(1))
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\tensor\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.compile(loss=tensorflow.keras.losses.MeanAbsolutePercentageError(), 
              optimizer=Adam(lr=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-8),
              metrics=['acc'])
model.fit(X_train_input, y_train, epochs=1000, batch_size=500, verbose=2)
# Out:
# Epoch 1/1000
#  - 5s - loss: 82.5904 - acc: 0.0000e+00
# Epoch 2/1000
#  - 4s - loss: 79.9772 - acc: 0.0000e+00
# Epoch 3/1000
#  - 4s - loss: 78.7344 - acc: 0.0000e+00
# Epoch 4/1000
#  - 4s - loss: 77.4013 - acc: 0.0000e+00
# Epoch 5/1000
#  - 4s - loss: 76.7752 - acc: 0.0000e+00
# Epoch 6/1000
#  - 4s - loss: 76.8549 - acc: 0.0000e+00
# Epoch 7/1000
#  - 4s - loss: 75.3094 - acc: 0.0000e+00
# Epoch 8/1000
#  - 4s - loss: 76.0214 - acc: 0.0000e+00
# Epoch 9/1000
#  - 4s - loss: 75.9914 - acc: 0.0000e+00
# Epoch 10/1000
#  - 4s - loss: 75.2042 - acc: 0.0000e+00
# Epoch 11/1000
#  - 4s - loss: 75.1206 - acc: 0.0000e+00
# Epoch 12/1000
#  - 4s - loss: 75.7040 - acc: 0.0000e+00
# Epoch 13/1000
#  - 4s - loss: 75.9132 - acc: 0.0000e+00
# Epoch 14/1000
#  - 4s - loss: 75.1373 - acc: 0.0000e+00
# Epoch 15/1000
#  - 5s - loss: 74.6524 - acc: 0.0000e+00
# Epoch 16/1000
#  - 4s - loss: 75.4338 - acc: 0.0000e+00
# Epoch 17/1000
#  - 4s - loss: 75.0034 - acc: 0.0000e+00
# Epoch 18/1000
#  - 4s - loss: 74.7510 - acc: 0.0000e+00
# Epoch 19/1000
#  - 4s - loss: 75.5921 - acc: 0.0000e+00
# Epoch 20/1000
#  - 4s - loss: 74.9967 - acc: 0.0000e+00
# Epoch 21/1000
#  - 4s - loss: 75.0281 - acc: 0.0000e+00
# Epoch 22/1000
#  - 4s - loss: 74.9477 - acc: 0.0000e+00
# Epoch 23/1000
#  - 4s - loss: 75.6323 - acc: 0.0000e+00
# Epoch 24/1000
#  - 4s - loss: 75.2619 - acc: 0.0000e+00
# Epoch 25/1000
#  - 4s - loss: 75.1358 - acc: 0.0000e+00
# Epoch 26/1000
#  - 4s - loss: 75.0662 - acc: 0.0000e+00
# Epoch 27/1000
#  - 4s - loss: 74.8987 - acc: 0.0000e+00
# Epoch 28/1000
#  - 4s - loss: 74.3980 - acc: 0.0000e+00
# Epoch 29/1000
#  - 4s - loss: 74.7784 - acc: 0.0000e+00
# Epoch 30/1000
#  - 4s - loss: 74.2833 - acc: 0.0000e+00
# Epoch 31/1000
#  - 4s - loss: 74.6488 - acc: 0.0000e+00
# Epoch 32/1000
#  - 5s - loss: 74.6811 - acc: 0.0000e+00
# Epoch 33/1000
#  - 4s - loss: 74.3151 - acc: 0.0000e+00
# Epoch 34/1000
#  - 4s - loss: 74.3864 - acc: 0.0000e+00
# Epoch 35/1000
#  - 5s - loss: 74.7884 - acc: 0.0000e+00
# Epoch 36/1000
#  - 4s - loss: 74.2848 - acc: 0.0000e+00
# Epoch 37/1000
#  - 5s - loss: 75.3109 - acc: 0.0000e+00
# Epoch 38/1000
#  - 4s - loss: 75.3121 - acc: 0.0000e+00
# Epoch 39/1000
#  - 5s - loss: 74.5446 - acc: 0.0000e+00
# Epoch 40/1000
#  - 4s - loss: 74.8277 - acc: 0.0000e+00
# Epoch 41/1000
#  - 5s - loss: 74.0126 - acc: 0.0000e+00
# Epoch 42/1000
#  - 5s - loss: 74.4371 - acc: 0.0000e+00
# Epoch 43/1000
#  - 5s - loss: 74.5362 - acc: 0.0000e+00
# Epoch 44/1000
#  - 5s - loss: 74.9135 - acc: 0.0000e+00
# Epoch 45/1000
#  - 4s - loss: 74.2681 - acc: 0.0000e+00
# Epoch 46/1000
#  - 4s - loss: 74.6571 - acc: 0.0000e+00
# Epoch 47/1000
#  - 4s - loss: 74.1787 - acc: 0.0000e+00
# Epoch 48/1000
#  - 4s - loss: 74.2386 - acc: 0.0000e+00
# Epoch 49/1000
#  - 4s - loss: 74.2191 - acc: 0.0000e+00
# Epoch 50/1000
#  - 4s - loss: 74.1905 - acc: 0.0000e+00
# Epoch 51/1000
#  - 4s - loss: 74.8892 - acc: 0.0000e+00
# Epoch 52/1000
#  - 4s - loss: 74.3613 - acc: 0.0000e+00
# Epoch 53/1000
#  - 4s - loss: 74.9726 - acc: 0.0000e+00
# Epoch 54/1000
#  - 4s - loss: 74.2090 - acc: 0.0000e+00
# Epoch 55/1000
#  - 4s - loss: 74.1511 - acc: 0.0000e+00
# Epoch 56/1000
#  - 4s - loss: 75.3741 - acc: 0.0000e+00
# Epoch 57/1000
#  - 4s - loss: 75.8933 - acc: 0.0000e+00
# Epoch 58/1000
#  - 4s - loss: 75.3855 - acc: 0.0000e+00
# Epoch 59/1000
#  - 4s - loss: 75.3134 - acc: 0.0000e+00
# Epoch 60/1000
#  - 4s - loss: 73.8981 - acc: 0.0000e+00
# Epoch 61/1000
#  - 4s - loss: 74.1226 - acc: 0.0000e+00
# Epoch 62/1000
#  - 4s - loss: 75.6962 - acc: 0.0000e+00
# Epoch 63/1000
#  - 4s - loss: 74.4987 - acc: 0.0000e+00
# Epoch 64/1000
#  - 4s - loss: 79.8051 - acc: 0.0000e+00
# Epoch 65/1000
#  - 4s - loss: 74.6815 - acc: 0.0000e+00
# Epoch 66/1000
#  - 4s - loss: 74.0767 - acc: 0.0000e+00
# Epoch 67/1000
#  - 4s - loss: 75.0524 - acc: 0.0000e+00
# Epoch 68/1000
#  - 4s - loss: 75.0954 - acc: 0.0000e+00
# Epoch 69/1000
#  - 4s - loss: 74.6250 - acc: 0.0000e+00
# Epoch 70/1000
#  - 4s - loss: 74.0890 - acc: 0.0000e+00
# Epoch 71/1000
#  - 4s - loss: 74.2414 - acc: 0.0000e+00
# Epoch 72/1000
#  - 4s - loss: 75.4585 - acc: 0.0000e+00
# Epoch 73/1000
#  - 4s - loss: 74.7219 - acc: 0.0000e+00
# Epoch 74/1000
#  - 4s - loss: 73.8307 - acc: 0.0000e+00
# Epoch 75/1000
#  - 4s - loss: 73.7490 - acc: 0.0000e+00
# Epoch 76/1000
#  - 4s - loss: 74.3380 - acc: 0.0000e+00
# Epoch 77/1000
#  - 4s - loss: 73.6781 - acc: 0.0000e+00
# Epoch 78/1000
#  - 4s - loss: 73.9964 - acc: 0.0000e+00
# Epoch 79/1000
#  - 4s - loss: 74.0198 - acc: 0.0000e+00
# Epoch 80/1000
#  - 4s - loss: 73.9528 - acc: 0.0000e+00
# Epoch 81/1000
#  - 4s - loss: 73.9488 - acc: 0.0000e+00
# Epoch 82/1000
#  - 4s - loss: 73.6914 - acc: 0.0000e+00
# Epoch 83/1000
#  - 4s - loss: 73.6716 - acc: 0.0000e+00
# Epoch 84/1000
#  - 4s - loss: 74.5388 - acc: 0.0000e+00
# Epoch 85/1000
#  - 5s - loss: 73.7419 - acc: 0.0000e+00
# Epoch 86/1000
#  - 4s - loss: 74.7833 - acc: 0.0000e+00
# Epoch 87/1000
#  - 5s - loss: 73.2812 - acc: 0.0000e+00
# Epoch 88/1000
#  - 5s - loss: 74.8761 - acc: 0.0000e+00
# Epoch 89/1000
#  - 4s - loss: 73.4996 - acc: 0.0000e+00
# Epoch 90/1000
#  - 4s - loss: 74.7873 - acc: 0.0000e+00
# Epoch 91/1000
#  - 4s - loss: 73.3301 - acc: 0.0000e+00
# Epoch 92/1000
#  - 4s - loss: 73.2222 - acc: 0.0000e+00
# Epoch 93/1000
#  - 4s - loss: 73.0524 - acc: 0.0000e+00
# Epoch 94/1000
#  - 4s - loss: 73.6325 - acc: 0.0000e+00
# Epoch 95/1000
#  - 4s - loss: 72.8385 - acc: 0.0000e+00
# Epoch 96/1000
#  - 4s - loss: 73.9649 - acc: 0.0000e+00
# Epoch 97/1000
#  - 4s - loss: 73.7802 - acc: 0.0000e+00
# Epoch 98/1000
#  - 4s - loss: 73.3943 - acc: 0.0000e+00
# Epoch 99/1000
#  - 4s - loss: 73.0939 - acc: 0.0000e+00
# Epoch 100/1000
#  - 4s - loss: 73.6675 - acc: 0.0000e+00
# Epoch 101/1000
#  - 4s - loss: 72.8025 - acc: 0.0000e+00
# Epoch 102/1000
#  - 4s - loss: 72.9937 - acc: 0.0000e+00
# Epoch 103/1000
#  - 4s - loss: 72.5429 - acc: 0.0000e+00
# Epoch 104/1000
#  - 4s - loss: 73.5048 - acc: 0.0000e+00
# Epoch 105/1000
#  - 4s - loss: 72.3870 - acc: 0.0000e+00
# Epoch 106/1000
#  - 5s - loss: 73.1520 - acc: 0.0000e+00
# Epoch 107/1000
#  - 5s - loss: 72.6279 - acc: 0.0000e+00
# Epoch 108/1000
#  - 4s - loss: 72.5715 - acc: 0.0000e+00
# Epoch 109/1000
#  - 4s - loss: 71.8989 - acc: 0.0000e+00
# Epoch 110/1000
#  - 4s - loss: 72.2910 - acc: 0.0000e+00
# Epoch 111/1000
#  - 4s - loss: 72.4026 - acc: 0.0000e+00
# Epoch 112/1000
#  - 4s - loss: 71.4998 - acc: 0.0000e+00
# Epoch 113/1000
#  - 4s - loss: 73.2380 - acc: 0.0000e+00
# Epoch 114/1000
#  - 4s - loss: 72.2953 - acc: 0.0000e+00
# Epoch 115/1000
#  - 4s - loss: 70.7458 - acc: 0.0000e+00
# Epoch 116/1000
#  - 4s - loss: 71.3557 - acc: 0.0000e+00
# Epoch 117/1000
#  - 4s - loss: 71.5000 - acc: 0.0000e+00
# Epoch 118/1000
#  - 4s - loss: 71.0374 - acc: 0.0000e+00
# Epoch 119/1000
#  - 4s - loss: 71.3997 - acc: 0.0000e+00
# Epoch 120/1000
#  - 4s - loss: 70.6593 - acc: 0.0000e+00
# Epoch 121/1000
#  - 4s - loss: 72.6401 - acc: 0.0000e+00
# Epoch 122/1000
#  - 4s - loss: 70.8152 - acc: 0.0000e+00
# Epoch 123/1000
#  - 4s - loss: 72.7896 - acc: 0.0000e+00
# Epoch 124/1000
#  - 5s - loss: 71.0326 - acc: 0.0000e+00
# Epoch 125/1000
#  - 4s - loss: 70.5241 - acc: 0.0000e+00
# Epoch 126/1000
#  - 4s - loss: 69.6946 - acc: 0.0000e+00
# Epoch 127/1000
#  - 4s - loss: 70.4966 - acc: 0.0000e+00
# Epoch 128/1000
#  - 5s - loss: 70.0385 - acc: 0.0000e+00
# Epoch 129/1000
#  - 4s - loss: 70.0631 - acc: 0.0000e+00
# Epoch 130/1000
#  - 4s - loss: 69.3687 - acc: 0.0000e+00
# Epoch 131/1000
#  - 4s - loss: 71.4273 - acc: 0.0000e+00
# Epoch 132/1000
#  - 4s - loss: 69.4786 - acc: 0.0000e+00
# Epoch 133/1000
#  - 5s - loss: 73.6587 - acc: 0.0000e+00
# Epoch 134/1000
#  - 4s - loss: 69.4164 - acc: 0.0000e+00
# Epoch 135/1000
#  - 5s - loss: 69.4544 - acc: 0.0000e+00
# Epoch 136/1000
#  - 6s - loss: 69.6215 - acc: 0.0000e+00
# Epoch 137/1000
#  - 6s - loss: 68.8585 - acc: 0.0000e+00
# Epoch 138/1000
#  - 5s - loss: 69.1160 - acc: 0.0000e+00
# Epoch 139/1000
#  - 5s - loss: 78.3372 - acc: 0.0000e+00
# Epoch 140/1000
#  - 5s - loss: 87.0845 - acc: 0.0000e+00
# Epoch 141/1000
#  - 4s - loss: 85.9665 - acc: 0.0000e+00
# Epoch 142/1000
#  - 4s - loss: 76.8311 - acc: 0.0000e+00
# Epoch 143/1000
#  - 4s - loss: 71.7959 - acc: 0.0000e+00
# Epoch 144/1000
#  - 4s - loss: 69.0867 - acc: 0.0000e+00
# Epoch 145/1000
#  - 4s - loss: 70.4830 - acc: 0.0000e+00
# Epoch 146/1000
#  - 4s - loss: 70.9758 - acc: 0.0000e+00
# Epoch 147/1000
#  - 5s - loss: 69.7939 - acc: 0.0000e+00
# Epoch 148/1000
#  - 5s - loss: 68.4061 - acc: 0.0000e+00
# Epoch 149/1000
#  - 4s - loss: 73.0694 - acc: 0.0000e+00
# Epoch 150/1000
#  - 5s - loss: 69.6558 - acc: 0.0000e+00
# Epoch 151/1000
#  - 4s - loss: 69.3625 - acc: 0.0000e+00
# Epoch 152/1000
#  - 4s - loss: 68.0410 - acc: 0.0000e+00
# Epoch 153/1000
#  - 4s - loss: 68.3429 - acc: 0.0000e+00
# Epoch 154/1000
#  - 5s - loss: 67.6786 - acc: 0.0000e+00
# Epoch 155/1000
#  - 5s - loss: 68.2599 - acc: 0.0000e+00
# Epoch 156/1000
#  - 5s - loss: 71.3713 - acc: 0.0000e+00
# Epoch 157/1000
#  - 5s - loss: 67.2986 - acc: 0.0000e+00
# Epoch 158/1000
#  - 5s - loss: 67.4474 - acc: 0.0000e+00
# Epoch 159/1000
#  - 5s - loss: 68.2397 - acc: 0.0000e+00
# Epoch 160/1000
#  - 5s - loss: 68.5441 - acc: 0.0000e+00
# Epoch 161/1000
#  - 5s - loss: 69.0449 - acc: 0.0000e+00
# Epoch 162/1000
#  - 5s - loss: 67.6309 - acc: 0.0000e+00
# Epoch 163/1000
#  - 5s - loss: 68.8194 - acc: 0.0000e+00
# Epoch 164/1000
#  - 5s - loss: 68.8274 - acc: 0.0000e+00
# Epoch 165/1000
#  - 5s - loss: 69.0073 - acc: 0.0000e+00
# Epoch 166/1000
#  - 5s - loss: 67.5328 - acc: 0.0000e+00
# Epoch 167/1000
#  - 4s - loss: 67.5611 - acc: 0.0000e+00
# Epoch 168/1000
#  - 4s - loss: 67.9683 - acc: 0.0000e+00
# Epoch 169/1000
#  - 4s - loss: 68.2761 - acc: 0.0000e+00
# Epoch 170/1000
#  - 4s - loss: 68.4436 - acc: 0.0000e+00
# Epoch 171/1000
#  - 4s - loss: 67.8104 - acc: 0.0000e+00
# Epoch 172/1000
#  - 4s - loss: 70.3901 - acc: 0.0000e+00
# Epoch 173/1000
#  - 4s - loss: 67.3180 - acc: 0.0000e+00
# Epoch 174/1000
#  - 4s - loss: 68.9220 - acc: 0.0000e+00
# Epoch 175/1000
#  - 4s - loss: 68.9721 - acc: 0.0000e+00
# Epoch 176/1000
#  - 4s - loss: 67.5292 - acc: 0.0000e+00
# Epoch 177/1000
#  - 4s - loss: 68.5156 - acc: 0.0000e+00
# Epoch 178/1000
#  - 4s - loss: 68.0323 - acc: 0.0000e+00
# Epoch 179/1000
#  - 5s - loss: 66.0755 - acc: 0.0000e+00
# Epoch 180/1000
#  - 4s - loss: 66.5336 - acc: 0.0000e+00
# Epoch 181/1000
#  - 4s - loss: 67.1121 - acc: 0.0000e+00
# Epoch 182/1000
#  - 4s - loss: 66.3985 - acc: 0.0000e+00
# Epoch 183/1000
#  - 5s - loss: 65.6206 - acc: 0.0000e+00
# Epoch 184/1000
#  - 4s - loss: 66.1391 - acc: 0.0000e+00
# Epoch 185/1000
#  - 4s - loss: 67.5105 - acc: 0.0000e+00
# Epoch 186/1000
#  - 5s - loss: 67.1113 - acc: 0.0000e+00
# Epoch 187/1000
#  - 4s - loss: 67.4194 - acc: 0.0000e+00
# Epoch 188/1000
#  - 4s - loss: 66.5767 - acc: 0.0000e+00
# Epoch 189/1000
#  - 4s - loss: 65.5506 - acc: 0.0000e+00
# Epoch 190/1000
#  - 4s - loss: 66.2883 - acc: 0.0000e+00
# Epoch 191/1000
#  - 4s - loss: 65.4856 - acc: 0.0000e+00
# Epoch 192/1000
#  - 4s - loss: 66.3230 - acc: 0.0000e+00
# Epoch 193/1000
#  - 4s - loss: 65.5597 - acc: 0.0000e+00
# Epoch 194/1000
#  - 4s - loss: 65.8826 - acc: 0.0000e+00
# Epoch 195/1000
#  - 4s - loss: 65.2173 - acc: 0.0000e+00
# Epoch 196/1000
#  - 4s - loss: 65.9609 - acc: 0.0000e+00
# Epoch 197/1000
#  - 4s - loss: 66.1892 - acc: 0.0000e+00
# Epoch 198/1000
#  - 4s - loss: 66.7665 - acc: 0.0000e+00
# Epoch 199/1000
#  - 4s - loss: 65.1923 - acc: 0.0000e+00
# Epoch 200/1000
#  - 4s - loss: 65.4454 - acc: 0.0000e+00
# Epoch 201/1000
#  - 4s - loss: 64.8695 - acc: 0.0000e+00
# Epoch 202/1000
#  - 4s - loss: 64.9260 - acc: 0.0000e+00
# Epoch 203/1000
#  - 4s - loss: 64.8948 - acc: 0.0000e+00
# Epoch 204/1000
#  - 4s - loss: 64.8878 - acc: 0.0000e+00
# Epoch 205/1000
#  - 4s - loss: 66.1679 - acc: 0.0000e+00
# Epoch 206/1000
#  - 4s - loss: 64.2800 - acc: 0.0000e+00
# Epoch 207/1000
#  - 4s - loss: 66.7215 - acc: 0.0000e+00
# Epoch 208/1000
#  - 5s - loss: 64.4526 - acc: 0.0000e+00
# Epoch 209/1000
#  - 4s - loss: 64.2155 - acc: 0.0000e+00
# Epoch 210/1000
#  - 4s - loss: 66.7921 - acc: 0.0000e+00
# Epoch 211/1000
#  - 5s - loss: 65.8388 - acc: 0.0000e+00
# Epoch 212/1000
#  - 5s - loss: 64.8236 - acc: 0.0000e+00
# Epoch 213/1000
#  - 5s - loss: 65.3291 - acc: 0.0000e+00
# Epoch 214/1000
#  - 4s - loss: 64.5103 - acc: 0.0000e+00
# Epoch 215/1000
#  - 4s - loss: 63.9892 - acc: 0.0000e+00
# Epoch 216/1000
#  - 4s - loss: 63.7349 - acc: 0.0000e+00
# Epoch 217/1000
#  - 4s - loss: 63.3123 - acc: 0.0000e+00
# Epoch 218/1000
#  - 4s - loss: 63.6809 - acc: 0.0000e+00
# Epoch 219/1000
#  - 4s - loss: 63.3779 - acc: 0.0000e+00
# Epoch 220/1000
#  - 4s - loss: 67.6416 - acc: 0.0000e+00
# Epoch 221/1000
#  - 4s - loss: 65.4968 - acc: 0.0000e+00
# Epoch 222/1000
#  - 4s - loss: 67.2104 - acc: 0.0000e+00
# Epoch 223/1000
#  - 4s - loss: 66.0280 - acc: 0.0000e+00
# Epoch 224/1000
#  - 4s - loss: 66.8895 - acc: 0.0000e+00
# Epoch 225/1000
#  - 4s - loss: 64.4027 - acc: 0.0000e+00
# Epoch 226/1000
#  - 4s - loss: 63.1181 - acc: 0.0000e+00
# Epoch 227/1000
#  - 4s - loss: 63.3543 - acc: 0.0000e+00
# Epoch 228/1000
#  - 4s - loss: 62.4867 - acc: 0.0000e+00
# Epoch 229/1000
#  - 4s - loss: 64.3917 - acc: 0.0000e+00
# Epoch 230/1000
#  - 4s - loss: 63.4029 - acc: 0.0000e+00
# Epoch 231/1000
#  - 4s - loss: 64.9739 - acc: 0.0000e+00
# Epoch 232/1000
#  - 4s - loss: 70.7685 - acc: 0.0000e+00
# Epoch 233/1000
#  - 4s - loss: 64.5661 - acc: 0.0000e+00
# Epoch 234/1000
#  - 4s - loss: 62.8312 - acc: 0.0000e+00
# Epoch 235/1000
#  - 4s - loss: 63.4236 - acc: 0.0000e+00
# Epoch 236/1000
#  - 5s - loss: 63.8440 - acc: 0.0000e+00
# Epoch 237/1000
#  - 4s - loss: 63.8520 - acc: 0.0000e+00
# Epoch 238/1000
#  - 4s - loss: 63.9135 - acc: 0.0000e+00
# Epoch 239/1000
#  - 4s - loss: 63.8666 - acc: 0.0000e+00
# Epoch 240/1000
#  - 4s - loss: 64.6330 - acc: 0.0000e+00
# Epoch 241/1000
#  - 4s - loss: 62.8192 - acc: 0.0000e+00
# Epoch 242/1000
#  - 4s - loss: 63.1526 - acc: 0.0000e+00
# Epoch 243/1000
#  - 4s - loss: 63.7753 - acc: 0.0000e+00
# Epoch 244/1000
#  - 5s - loss: 63.8160 - acc: 0.0000e+00
# Epoch 245/1000
#  - 4s - loss: 61.8595 - acc: 0.0000e+00
# Epoch 246/1000
#  - 4s - loss: 61.6368 - acc: 0.0000e+00
# Epoch 247/1000
#  - 4s - loss: 62.7625 - acc: 0.0000e+00
# Epoch 248/1000
#  - 4s - loss: 64.3620 - acc: 0.0000e+00
# Epoch 249/1000
#  - 4s - loss: 63.1814 - acc: 0.0000e+00
# Epoch 250/1000
#  - 5s - loss: 62.1352 - acc: 0.0000e+00
# Epoch 251/1000
#  - 4s - loss: 61.8543 - acc: 0.0000e+00
# Epoch 252/1000
#  - 4s - loss: 62.2618 - acc: 0.0000e+00
# Epoch 253/1000
#  - 4s - loss: 62.1250 - acc: 0.0000e+00
# Epoch 254/1000
#  - 4s - loss: 62.3102 - acc: 0.0000e+00
# Epoch 255/1000
#  - 5s - loss: 60.7115 - acc: 0.0000e+00
# Epoch 256/1000
#  - 5s - loss: 61.7319 - acc: 0.0000e+00
# Epoch 257/1000
#  - 5s - loss: 61.6105 - acc: 0.0000e+00
# Epoch 258/1000
#  - 4s - loss: 61.8359 - acc: 0.0000e+00
# Epoch 259/1000
#  - 4s - loss: 66.0251 - acc: 0.0000e+00
# Epoch 260/1000
#  - 4s - loss: 63.0710 - acc: 0.0000e+00
# Epoch 261/1000
#  - 4s - loss: 61.1500 - acc: 0.0000e+00
# Epoch 262/1000
#  - 5s - loss: 63.2619 - acc: 0.0000e+00
# Epoch 263/1000
#  - 4s - loss: 60.8013 - acc: 0.0000e+00
# Epoch 264/1000
#  - 4s - loss: 63.4694 - acc: 0.0000e+00
# Epoch 265/1000
#  - 4s - loss: 63.3092 - acc: 0.0000e+00
# Epoch 266/1000
#  - 4s - loss: 61.2286 - acc: 0.0000e+00
# Epoch 267/1000
#  - 4s - loss: 60.0787 - acc: 0.0000e+00
# Epoch 268/1000
#  - 4s - loss: 61.7162 - acc: 0.0000e+00
# Epoch 269/1000
#  - 4s - loss: 61.3921 - acc: 0.0000e+00
# Epoch 270/1000
#  - 4s - loss: 60.0641 - acc: 0.0000e+00
# Epoch 271/1000
#  - 4s - loss: 60.3532 - acc: 0.0000e+00
# Epoch 272/1000
#  - 4s - loss: 63.2103 - acc: 0.0000e+00
# Epoch 273/1000
#  - 4s - loss: 61.8288 - acc: 0.0000e+00
# Epoch 274/1000
#  - 4s - loss: 61.8165 - acc: 0.0000e+00
# Epoch 275/1000
#  - 4s - loss: 59.8500 - acc: 0.0000e+00
# Epoch 276/1000
#  - 5s - loss: 60.3805 - acc: 0.0000e+00
# Epoch 277/1000
#  - 4s - loss: 59.4027 - acc: 0.0000e+00
# Epoch 278/1000
#  - 4s - loss: 59.4678 - acc: 0.0000e+00
# Epoch 279/1000
#  - 4s - loss: 59.3248 - acc: 0.0000e+00
# Epoch 280/1000
#  - 4s - loss: 62.2526 - acc: 0.0000e+00
# Epoch 281/1000
#  - 4s - loss: 60.9209 - acc: 0.0000e+00
# Epoch 282/1000
#  - 4s - loss: 60.8271 - acc: 0.0000e+00
# Epoch 283/1000
#  - 4s - loss: 58.2201 - acc: 0.0000e+00
# Epoch 284/1000
#  - 4s - loss: 63.0629 - acc: 0.0000e+00
# Epoch 285/1000
#  - 4s - loss: 59.3417 - acc: 0.0000e+00
# Epoch 286/1000
#  - 4s - loss: 59.6314 - acc: 0.0000e+00
# Epoch 287/1000
#  - 4s - loss: 58.9232 - acc: 0.0000e+00
# Epoch 288/1000
#  - 4s - loss: 61.2498 - acc: 0.0000e+00
# Epoch 289/1000
#  - 4s - loss: 60.6573 - acc: 0.0000e+00
# Epoch 290/1000
#  - 4s - loss: 58.9842 - acc: 0.0000e+00
# Epoch 291/1000
#  - 4s - loss: 60.3769 - acc: 0.0000e+00
# Epoch 292/1000
#  - 4s - loss: 57.9509 - acc: 0.0000e+00
# Epoch 293/1000
#  - 4s - loss: 58.4563 - acc: 0.0000e+00
# Epoch 294/1000
#  - 4s - loss: 61.3950 - acc: 0.0000e+00
# Epoch 295/1000
#  - 4s - loss: 59.0735 - acc: 0.0000e+00
# Epoch 296/1000
#  - 4s - loss: 59.7727 - acc: 0.0000e+00
# Epoch 297/1000
#  - 4s - loss: 59.3856 - acc: 0.0000e+00
# Epoch 298/1000
#  - 4s - loss: 59.6543 - acc: 0.0000e+00
# Epoch 299/1000
#  - 4s - loss: 59.6880 - acc: 0.0000e+00
# Epoch 300/1000
#  - 4s - loss: 59.0658 - acc: 0.0000e+00
# Epoch 301/1000
#  - 4s - loss: 58.0899 - acc: 0.0000e+00
# Epoch 302/1000
#  - 4s - loss: 56.9633 - acc: 0.0000e+00
# Epoch 303/1000
#  - 4s - loss: 58.4102 - acc: 0.0000e+00
# Epoch 304/1000
#  - 4s - loss: 59.4800 - acc: 0.0000e+00
# Epoch 305/1000
#  - 4s - loss: 58.6283 - acc: 0.0000e+00
# Epoch 306/1000
#  - 4s - loss: 58.5163 - acc: 0.0000e+00
# Epoch 307/1000
#  - 4s - loss: 57.0888 - acc: 0.0000e+00
# Epoch 308/1000
#  - 4s - loss: 68.9881 - acc: 0.0000e+00
# Epoch 309/1000
#  - 4s - loss: 59.1030 - acc: 0.0000e+00
# Epoch 310/1000
#  - 4s - loss: 58.1580 - acc: 0.0000e+00
# Epoch 311/1000
#  - 4s - loss: 57.0922 - acc: 0.0000e+00
# Epoch 312/1000
#  - 4s - loss: 56.5324 - acc: 0.0000e+00
# Epoch 313/1000
#  - 4s - loss: 57.5088 - acc: 0.0000e+00
# Epoch 314/1000
#  - 4s - loss: 61.2261 - acc: 0.0000e+00
# Epoch 315/1000
#  - 4s - loss: 57.3418 - acc: 0.0000e+00
# Epoch 316/1000
#  - 4s - loss: 55.5981 - acc: 0.0000e+00
# Epoch 317/1000
#  - 4s - loss: 58.2690 - acc: 0.0000e+00
# Epoch 318/1000
#  - 4s - loss: 58.1436 - acc: 0.0000e+00
# Epoch 319/1000
#  - 4s - loss: 59.9985 - acc: 0.0000e+00
# Epoch 320/1000
#  - 4s - loss: 56.6739 - acc: 0.0000e+00
# Epoch 321/1000
#  - 4s - loss: 57.8166 - acc: 0.0000e+00
# Epoch 322/1000
#  - 4s - loss: 56.5778 - acc: 0.0000e+00
# Epoch 323/1000
#  - 4s - loss: 58.6677 - acc: 0.0000e+00
# Epoch 324/1000
#  - 4s - loss: 57.4194 - acc: 0.0000e+00
# Epoch 325/1000
#  - 4s - loss: 57.6217 - acc: 0.0000e+00
# Epoch 326/1000
#  - 4s - loss: 59.8963 - acc: 0.0000e+00
# Epoch 327/1000
#  - 4s - loss: 57.8212 - acc: 0.0000e+00
# Epoch 328/1000
#  - 4s - loss: 55.7997 - acc: 0.0000e+00
# Epoch 329/1000
#  - 4s - loss: 58.0502 - acc: 0.0000e+00
# Epoch 330/1000
#  - 4s - loss: 60.2364 - acc: 0.0000e+00
# Epoch 331/1000
#  - 4s - loss: 54.9553 - acc: 0.0000e+00
# Epoch 332/1000
#  - 4s - loss: 55.0056 - acc: 0.0000e+00
# Epoch 333/1000
#  - 4s - loss: 61.3745 - acc: 0.0000e+00
# Epoch 334/1000
#  - 4s - loss: 57.6123 - acc: 0.0000e+00
# Epoch 335/1000
#  - 4s - loss: 57.6730 - acc: 0.0000e+00
# Epoch 336/1000
#  - 4s - loss: 59.6329 - acc: 0.0000e+00
# Epoch 337/1000
#  - 4s - loss: 54.4895 - acc: 0.0000e+00
# Epoch 338/1000
#  - 4s - loss: 64.4705 - acc: 0.0000e+00
# Epoch 339/1000
#  - 4s - loss: 60.1931 - acc: 0.0000e+00
# Epoch 340/1000
#  - 4s - loss: 55.9949 - acc: 0.0000e+00
# Epoch 341/1000
#  - 4s - loss: 56.0277 - acc: 0.0000e+00
# Epoch 342/1000
#  - 4s - loss: 64.1760 - acc: 0.0000e+00
# Epoch 343/1000
#  - 4s - loss: 59.8330 - acc: 0.0000e+00
# Epoch 344/1000
#  - 5s - loss: 56.5243 - acc: 0.0000e+00
# Epoch 345/1000
#  - 5s - loss: 54.6276 - acc: 0.0000e+00
# Epoch 346/1000
#  - 4s - loss: 56.1392 - acc: 0.0000e+00
# Epoch 347/1000
#  - 4s - loss: 55.6534 - acc: 0.0000e+00
# Epoch 348/1000
#  - 4s - loss: 58.8417 - acc: 0.0000e+00
# Epoch 349/1000
#  - 4s - loss: 55.7198 - acc: 0.0000e+00
# Epoch 350/1000
#  - 4s - loss: 54.2158 - acc: 0.0000e+00
# Epoch 351/1000
#  - 4s - loss: 54.4862 - acc: 0.0000e+00
# Epoch 352/1000
#  - 4s - loss: 62.8494 - acc: 0.0000e+00
# Epoch 353/1000
#  - 4s - loss: 55.0478 - acc: 0.0000e+00
# Epoch 354/1000
#  - 5s - loss: 57.1551 - acc: 0.0000e+00
# Epoch 355/1000
#  - 4s - loss: 58.7528 - acc: 0.0000e+00
# Epoch 356/1000
#  - 5s - loss: 53.8200 - acc: 0.0000e+00
# Epoch 357/1000
#  - 5s - loss: 53.6172 - acc: 0.0000e+00
# Epoch 358/1000
#  - 4s - loss: 55.9263 - acc: 0.0000e+00
# Epoch 359/1000
#  - 4s - loss: 54.0832 - acc: 0.0000e+00
# Epoch 360/1000
#  - 4s - loss: 53.9953 - acc: 0.0000e+00
# Epoch 361/1000
#  - 4s - loss: 56.7831 - acc: 0.0000e+00
# Epoch 362/1000
#  - 4s - loss: 58.1227 - acc: 0.0000e+00
# Epoch 363/1000
#  - 4s - loss: 54.3992 - acc: 0.0000e+00
# Epoch 364/1000
#  - 4s - loss: 54.4644 - acc: 0.0000e+00
# Epoch 365/1000
#  - 4s - loss: 55.9953 - acc: 0.0000e+00
# Epoch 366/1000
#  - 4s - loss: 55.3964 - acc: 0.0000e+00
# Epoch 367/1000
#  - 4s - loss: 52.4859 - acc: 0.0000e+00
# Epoch 368/1000
#  - 4s - loss: 54.2543 - acc: 0.0000e+00
# Epoch 369/1000
#  - 4s - loss: 54.2570 - acc: 0.0000e+00
# Epoch 370/1000
#  - 4s - loss: 54.1000 - acc: 0.0000e+00
# Epoch 371/1000
#  - 5s - loss: 53.5805 - acc: 0.0000e+00
# Epoch 372/1000
#  - 5s - loss: 53.5218 - acc: 0.0000e+00
# Epoch 373/1000
#  - 4s - loss: 54.3925 - acc: 0.0000e+00
# Epoch 374/1000
#  - 4s - loss: 59.8656 - acc: 0.0000e+00
# Epoch 375/1000
#  - 4s - loss: 56.5714 - acc: 0.0000e+00
# Epoch 376/1000
#  - 4s - loss: 86.5419 - acc: 0.0000e+00
# Epoch 377/1000
#  - 5s - loss: 65.7269 - acc: 0.0000e+00
# Epoch 378/1000
#  - 4s - loss: 54.6997 - acc: 0.0000e+00
# Epoch 379/1000
#  - 4s - loss: 59.8820 - acc: 0.0000e+00
# Epoch 380/1000
#  - 4s - loss: 53.1300 - acc: 0.0000e+00
# Epoch 381/1000
#  - 4s - loss: 54.9067 - acc: 0.0000e+00
# Epoch 382/1000
#  - 4s - loss: 52.1812 - acc: 0.0000e+00
# Epoch 383/1000
#  - 4s - loss: 60.9503 - acc: 0.0000e+00
# Epoch 384/1000
#  - 4s - loss: 81.3825 - acc: 0.0000e+00
# Epoch 385/1000
#  - 4s - loss: 54.0575 - acc: 0.0000e+00
# Epoch 386/1000
#  - 4s - loss: 62.0999 - acc: 0.0000e+00
# Epoch 387/1000
#  - 4s - loss: 69.5682 - acc: 0.0000e+00
# Epoch 388/1000
